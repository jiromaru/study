# %% [markdown]
# # ランダムフォレストによる特徴量選択について
# HousePrices Advanced Regression Techniquesのコンペティションにおいて、特徴量を絞るためにsklearnのSelectFromModelランダムフォレストを用いた。
# これについてもう少し調べてみる。

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestRegressor
import pandas as pd
# Out:
# C:\Users\hirou\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
#csvファイルの読み込みデータフレームを作成
#データはHousePrices Advanced Regression Techniquesのコンペティションより取得
train_df = pd.read_csv("train.csv", header=0)
SP=train_df[["Id","SalePrice"]]

# %%
#81項目ある
len(train_df.dtypes)
# Out:
# 81

# %%
#欠損値の処理をする

#数値変数はmedianで穴埋め
train_df = train_df.fillna(train_df.median())

#カテゴリ変数は最大回数の値で穴埋め
null_list=list(train_df.isnull().sum()[train_df.isnull().sum()>1].index)
for i in null_list:
    max=train_df[i].value_counts()[0]
    train_df.loc[(train_df[i].isnull()),i]=max
    
#カテゴリ変数をダミー変数化
train_df=pd.get_dummies(train_df)

#特徴量とターゲットに分割
train=train_df.drop(["Id","SalePrice"],axis=1)
target=train_df["SalePrice"]

#trainの項目名のリストを作成
col=list(train.columns)

# %%
print("各処理後の特徴量の項目数 : ",len(train.dtypes))
# Out:
# 各処理後の特徴量の項目数 :  303

# %% [markdown]
# ##  確認したいこと
# SelectFromModelとRandomForestRegressorを用いた項目の絞りかたが、RandomForestRegressorのfeature_importances_に基づいて選択されていることを確認する。

# %%
#SelectFromModelとRandomForestRegressorによって項目を絞る処理
selector = SelectFromModel(RandomForestRegressor(n_estimators=100, random_state=42), threshold="median")
selector.fit(train,target)
x_selected = selector.transform(train)
selector_ver=pd.DataFrame({"col" : col , "bool" : selector.get_support()})
selector_ver[selector_ver["bool"]==True].reset_index(drop=True)
# Out:
#                        col  bool
# 0               MSSubClass  True
# 1              LotFrontage  True
# 2                  LotArea  True
# 3              OverallQual  True
# 4              OverallCond  True
# 5                YearBuilt  True
# 6             YearRemodAdd  True
# 7               MasVnrArea  True
# 8               BsmtFinSF1  True
# 9               BsmtFinSF2  True
# 10               BsmtUnfSF  True
# 11             TotalBsmtSF  True
# 12                1stFlrSF  True
# 13                2ndFlrSF  True
# 14            LowQualFinSF  True
# 15               GrLivArea  True
# 16            BsmtFullBath  True
# 17            BsmtHalfBath  True
# 18                FullBath  True
# 19                HalfBath  True
# 20            BedroomAbvGr  True
# 21            KitchenAbvGr  True
# 22            TotRmsAbvGrd  True
# 23              Fireplaces  True
# 24             GarageYrBlt  True
# 25              GarageCars  True
# 26              GarageArea  True
# 27              WoodDeckSF  True
# 28             OpenPorchSF  True
# 29           EnclosedPorch  True
# ..                     ...   ...
# 122           CentralAir_N  True
# 123           CentralAir_Y  True
# 124       Electrical_SBrkr  True
# 125         KitchenQual_Ex  True
# 126         KitchenQual_Gd  True
# 127         KitchenQual_TA  True
# 128         Functional_Mod  True
# 129         Functional_Typ  True
# 130        FireplaceQu_380  True
# 131         FireplaceQu_Ex  True
# 132         FireplaceQu_Gd  True
# 133         FireplaceQu_TA  True
# 134      GarageType_Attchd  True
# 135     GarageType_BuiltIn  True
# 136      GarageType_Detchd  True
# 137       GarageFinish_Fin  True
# 138       GarageFinish_RFn  True
# 139       GarageFinish_Unf  True
# 140          GarageQual_TA  True
# 141          GarageCond_TA  True
# 142           PavedDrive_N  True
# 143           PavedDrive_Y  True
# 144              Fence_157  True
# 145            Fence_MnPrv  True
# 146           SaleType_New  True
# 147            SaleType_WD  True
# 148  SaleCondition_Abnorml  True
# 149   SaleCondition_Family  True
# 150   SaleCondition_Normal  True
# 151  SaleCondition_Partial  True
#
# [152 rows x 2 columns]

# %%
#RandomForestのfeature_importances_で項目を絞る処理
forest=RandomForestRegressor(n_estimators=100, random_state=42)
forest.fit(train,target)
imp=list(forest.feature_importances_)

imp_ver=pd.DataFrame({"col" : col,"imp" : imp})
imp_ver=imp_ver.sort_values(by="imp",ascending=False).reset_index(drop=True)

# %%
#feature_importances_の上から152番目(median)まで取得
imp_ver[:imp_ver[imp_ver["imp"]==imp_ver["imp"].median()].index[0]+1]
# Out:
#                       col       imp
# 0             OverallQual  0.580222
# 1               GrLivArea  0.107616
# 2             TotalBsmtSF  0.036829
# 3                2ndFlrSF  0.032555
# 4              BsmtFinSF1  0.030640
# 5              GarageCars  0.025565
# 6                1stFlrSF  0.024236
# 7              GarageArea  0.012593
# 8                 LotArea  0.011945
# 9               YearBuilt  0.008742
# 10               FullBath  0.007892
# 11           YearRemodAdd  0.007123
# 12            LotFrontage  0.006650
# 13           TotRmsAbvGrd  0.006013
# 14             MasVnrArea  0.005114
# 15            OpenPorchSF  0.004757
# 16            GarageYrBlt  0.004661
# 17              BsmtUnfSF  0.004605
# 18             WoodDeckSF  0.004317
# 19            OverallCond  0.004163
# 20                 MoSold  0.002999
# 21            BsmtQual_Ex  0.002984
# 22             Fireplaces  0.002325
# 23         KitchenQual_Gd  0.002270
# 24      GarageType_Detchd  0.002065
# 25             MSSubClass  0.001939
# 26            BsmtQual_Gd  0.001897
# 27           BedroomAbvGr  0.001664
# 28            MSZoning_RM  0.001656
# 29      GarageType_Attchd  0.001646
# ..                    ...       ...
# 122             Fence_157  0.000169
# 123           BsmtCond_TA  0.000166
# 124     HouseStyle_1.5Fin  0.000161
# 125   Neighborhood_Timber  0.000155
# 126          HeatingQC_Fa  0.000155
# 127          LowQualFinSF  0.000152
# 128   Exterior2nd_Plywood  0.000151
# 129           BsmtCond_Fa  0.000147
# 130   Exterior1st_Plywood  0.000144
# 131  Neighborhood_ClearCr  0.000144
# 132          HeatingQC_Gd  0.000143
# 133     Foundation_CBlock  0.000139
# 134      BsmtFinType1_Rec  0.000136
# 135  Neighborhood_Somerst  0.000135
# 136   Exterior2nd_CmentBd  0.000134
# 137   Exterior2nd_Wd Sdng  0.000134
# 138     HouseStyle_1Story  0.000133
# 139           BsmtCond_Gd  0.000123
# 140       BsmtExposure_Mn  0.000119
# 141      BsmtFinType2_Unf  0.000118
# 142        RoofStyle_Flat  0.000114
# 143           Fence_MnPrv  0.000112
# 144      Electrical_SBrkr  0.000110
# 145       LandContour_Low  0.000108
# 146  Neighborhood_BrkSide  0.000107
# 147        Functional_Mod  0.000106
# 148         LotConfig_FR2  0.000106
# 149           MSZoning_FV  0.000104
# 150  Neighborhood_NoRidge  0.000099
# 151   Exterior1st_CemntBd  0.000098
#
# [152 rows x 2 columns]

# %%
set(list(selector_ver["col"]))==set(list(imp_ver["col"]))
# Out:
# True

# %% [markdown]
# ### 結論
# 思っていた通り、SelectFromModelをランダムフォレスト回帰で用いた場合、ランダムフォレスト回帰のfeature_importances_に基づいて選択されていることを確認することができた。

# %% [markdown]
# ### メモ
# そもそもfeature_importances_はどのように計算されているのか。
# ランダムフォレストを行うにあたり、ある項目のデータをランダムに振りなおした場合に精度がどれくらい変わるか、というのを全項目で行っている。
# x1=(2,3,4,),x2=(5,2,4),x3=(6,3,2)のようなデータがあった場合、x1=(5,3,4,),x2=(6,2,4),x3=(2,3,2)のように値を入れ替えてランダムフォレストを行い精度比較するというイメージ。これを二次元目、三次元目の値についても行ったときに、一番精度に影響があった項目が一番重要度が大きいという考え方。
